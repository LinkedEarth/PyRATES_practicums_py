# %%
import pyleoclim as pyleo
pyleo.utils.available_dataset_names()
# Out:
# ['SOI',
#  'NINO3',
#  'HadCRUT5',
#  'AIR',
#  'LR04',
#  'AACO2',
#  'EDC-dD',
#  'GISP2',
#  'cenogrid_d18O',
#  'cenogrid_d13C']

# %%
nino3 = pyleo.utils.load_dataset('NINO3')
gmst = pyleo.utils.load_dataset('HadCRUT5')
ms = nino3 & gmst
ms.plot()
# Out:
# (<Figure size 1000x400 with 1 Axes>,
#  <Axes: xlabel='Time [year C.E.]', ylabel='value'>)

# %%
dflt_corr = gmst.correlation(nino3)
# Out:
# {}
# Evaluating association on surrogate pairs:   0%|          | 0/1000 [00:00<?, ?it/s]
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# Evaluating association on surrogate pairs:  12%|█▏        | 116/1000 [00:00<00:00, 1152.68it/s]
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# ...

# %%
print(dflt_corr)
# Out:
#   correlation  p-value      signif. (α: 0.05)
# -------------  ---------  -------------------
#      0.238683  < 1e-6                       1

# %% [markdown]
# - effects of trends
# - effects of autocorrelation (classic T-test)

# %%
gmst_d = gmst.detrend()
nino3_d = nino3.detrend()
corr_d = gmst_d.correlation(nino3_d, statistic='pearsonr',method='phaseran')
# Out:
# {}
# Evaluating association on surrogate pairs:   0%|          | 0/1000 [00:00<?, ?it/s]
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# Evaluating association on surrogate pairs:  24%|██▍       | 238/1000 [00:00<00:00, 1173.42it/s]
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# ...

# %%
corr_d.p
# Out:
# 0.0
